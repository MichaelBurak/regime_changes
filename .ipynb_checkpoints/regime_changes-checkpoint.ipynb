# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Survival-Analysis-of-Adverse-Regime-Changes:" data-toc-modified-id="Survival-Analysis-of-Adverse-Regime-Changes:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Survival Analysis of Adverse Regime Changes:</a></span></li><li><span><a href="#Imports-and-reading-in-data" data-toc-modified-id="Imports-and-reading-in-data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Imports and reading in data</a></span></li><li><span><a href="#Focusing-on-duration" data-toc-modified-id="Focusing-on-duration-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Focusing on duration</a></span><ul class="toc-item"><li><span><a href="#Creating-'time_begin'-and-'time_end'-features" data-toc-modified-id="Creating-'time_begin'-and-'time_end'-features-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Creating 'time_begin' and 'time_end' features</a></span></li></ul></li><li><span><a href="#Minor-data-cleaning" data-toc-modified-id="Minor-data-cleaning-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Minor data cleaning</a></span></li><li><span><a href="#Geographical-plotting-test---just-the-most-turbulent-year" data-toc-modified-id="Geographical-plotting-test---just-the-most-turbulent-year-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Geographical plotting test - just the most turbulent year</a></span><ul class="toc-item"><li><span><a href="#Creation-of-one-hot-encoded-variables-of-POLITYX-and-COUNTRY" data-toc-modified-id="Creation-of-one-hot-encoded-variables-of-POLITYX-and-COUNTRY-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Creation of one hot encoded variables of POLITYX and COUNTRY</a></span></li></ul></li><li><span><a href="#Survival-analysis---TO-DO:-By-country/region" data-toc-modified-id="Survival-analysis---TO-DO:-By-country/region-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Survival analysis - TO DO: By country/region</a></span><ul class="toc-item"><li><span><a href="#First-converting-time_begin-and-time_end-to-accepted-Lifelines-format" data-toc-modified-id="First-converting-time_begin-and-time_end-to-accepted-Lifelines-format-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>First converting time_begin and time_end to accepted Lifelines format</a></span></li><li><span><a href="#Kaplan-Meier-Fitter" data-toc-modified-id="Kaplan-Meier-Fitter-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Kaplan Meier Fitter</a></span><ul class="toc-item"><li><span><a href="#Plotting-results-in-months" data-toc-modified-id="Plotting-results-in-months-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Plotting results in months</a></span></li></ul></li><li><span><a href="#NelsonAalenFitter-for-cumulative-hazard-function" data-toc-modified-id="NelsonAalenFitter-for-cumulative-hazard-function-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>NelsonAalenFitter for cumulative hazard function</a></span></li></ul></li><li><span><a href="#TO-DO:-implementing-right/left-censorship-of-birth/death-events-via.-groupby-country-and-time-resampling" data-toc-modified-id="TO-DO:-implementing-right/left-censorship-of-birth/death-events-via.-groupby-country-and-time-resampling-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>TO DO: implementing right/left censorship of birth/death events via. groupby country and time resampling</a></span></li><li><span><a href="#Geographic-plotting" data-toc-modified-id="Geographic-plotting-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Geographic plotting</a></span></li></ul></div>

# %% [markdown]
# # Survival Analysis of Adverse Regime Changes:
# - Dataset available at: http://www.systemicpeace.org/inscrdata.html
# - Utilizing the fantastic Lifelines package for Survival Analysis and adapting examples from https://lifelines.readthedocs.io/en/latest/index.html
# - Beginning EDA and survival analysis towards a study of regime changes' effects on the global market

# %% [markdown]
# # Imports and reading in data

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np 
import pandas as pd

# %%
df = pd.read_excel('PITF Adverse Regime Change 2018.xls', index_col=None) 

df.head(10)
# Out:
#        COUNTRY SCODE  CCODE  YEAR  MOBEGIN  YRBEGIN  MOEND  YREND  PTYPE  \
# 0  Afghanistan   AFG    700  1978        4     1978     12   1979      3
# 1  Afghanistan   AFG    700  1979        4     1978     12   1979      3
# 2  Afghanistan   AFG    700  1992        4     1992      9   1996      3
# 3  Afghanistan   AFG    700  1993        4     1992      9   1996      3
# 4  Afghanistan   AFG    700  1994        4     1992      9   1996      3
# 5  Afghanistan   AFG    700  1995        4     1992      9   1996      3
# 6  Afghanistan   AFG    700  1996        4     1992      9   1996      3
# 7  Afghanistan   AFG    700  2001       11     2001      6   2002      3
# 8  Afghanistan   AFG    700  2002       11     2001      6   2002      3
# 9      Albania   ALB    339  1996        5     1996      5   1996      3
#
#    MAGFAIL  MAGCOL  MAGVIOL  MAGAVE  \
# 0        2       1        4     2.5
# 1        2       1        4     2.5
# 2        4       1        4     3.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 353 entries, 0 to 352
# Data columns (total 16 columns):
# COUNTRY    353 non-null object
# SCODE      353 non-null object
# CCODE      353 non-null int64
# YEAR       353 non-null int64
# MOBEGIN    353 non-null int64
# YRBEGIN    353 non-null int64
# MOEND      353 non-null int64
# YREND      353 non-null int64
# PTYPE      353 non-null int64
# MAGFAIL    353 non-null int64
# MAGCOL     353 non-null int64
# MAGVIOL    353 non-null int64
# MAGAVE     353 non-null float64
# DESC       136 non-null object
# POLITYX    136 non-null object
# DESC2      136 non-null float64
# dtypes: float64(2), int64(10), object(4)
# memory usage: 44.2+ KB

# %% [markdown]
# # Focusing on duration
# - Time of beginning and end of regime change through YRBEGIN, YREND, MOBEGIN, MOEND features are of key interest

# %% [markdown]
# ## Creating 'time_begin' and 'time_end' features
# - These capture both month and year as Pandas datetime features

# %%
df['time_begin'] = df['YRBEGIN'].astype(str)  + "-" +df['MOBEGIN'].astype(str) 

df.head(10)
# Out:
#        COUNTRY SCODE  CCODE  YEAR  MOBEGIN  YRBEGIN  MOEND  YREND  PTYPE  \
# 0  Afghanistan   AFG    700  1978        4     1978     12   1979      3
# 1  Afghanistan   AFG    700  1979        4     1978     12   1979      3
# 2  Afghanistan   AFG    700  1992        4     1992      9   1996      3
# 3  Afghanistan   AFG    700  1993        4     1992      9   1996      3
# 4  Afghanistan   AFG    700  1994        4     1992      9   1996      3
# 5  Afghanistan   AFG    700  1995        4     1992      9   1996      3
# 6  Afghanistan   AFG    700  1996        4     1992      9   1996      3
# 7  Afghanistan   AFG    700  2001       11     2001      6   2002      3
# 8  Afghanistan   AFG    700  2002       11     2001      6   2002      3
# 9      Albania   ALB    339  1996        5     1996      5   1996      3
#
#    MAGFAIL  MAGCOL  MAGVIOL  MAGAVE  \
# 0        2       1        4     2.5
# 1        2       1        4     2.5
# 2        4       1        4     3.0
# ...

# %%
df['time_begin'] = pd.to_datetime(df['time_begin'],  errors='coerce')

df.head(10)
# Out:
#        COUNTRY SCODE  CCODE  YEAR  MOBEGIN  YRBEGIN  MOEND  YREND  PTYPE  \
# 0  Afghanistan   AFG    700  1978        4     1978     12   1979      3
# 1  Afghanistan   AFG    700  1979        4     1978     12   1979      3
# 2  Afghanistan   AFG    700  1992        4     1992      9   1996      3
# 3  Afghanistan   AFG    700  1993        4     1992      9   1996      3
# 4  Afghanistan   AFG    700  1994        4     1992      9   1996      3
# 5  Afghanistan   AFG    700  1995        4     1992      9   1996      3
# 6  Afghanistan   AFG    700  1996        4     1992      9   1996      3
# 7  Afghanistan   AFG    700  2001       11     2001      6   2002      3
# 8  Afghanistan   AFG    700  2002       11     2001      6   2002      3
# 9      Albania   ALB    339  1996        5     1996      5   1996      3
#
#    MAGFAIL  MAGCOL  MAGVIOL  MAGAVE  \
# 0        2       1        4     2.5
# 1        2       1        4     2.5
# 2        4       1        4     3.0
# ...

# %%
df['time_end'] = pd.to_datetime((df['YREND'].astype(str)  + "-" +df['MOEND'].astype(str)),  errors='coerce')

df.head(10)
# Out:
#        COUNTRY SCODE  CCODE  YEAR  MOBEGIN  YRBEGIN  MOEND  YREND  PTYPE  \
# 0  Afghanistan   AFG    700  1978        4     1978     12   1979      3
# 1  Afghanistan   AFG    700  1979        4     1978     12   1979      3
# 2  Afghanistan   AFG    700  1992        4     1992      9   1996      3
# 3  Afghanistan   AFG    700  1993        4     1992      9   1996      3
# 4  Afghanistan   AFG    700  1994        4     1992      9   1996      3
# 5  Afghanistan   AFG    700  1995        4     1992      9   1996      3
# 6  Afghanistan   AFG    700  1996        4     1992      9   1996      3
# 7  Afghanistan   AFG    700  2001       11     2001      6   2002      3
# 8  Afghanistan   AFG    700  2002       11     2001      6   2002      3
# 9      Albania   ALB    339  1996        5     1996      5   1996      3
#
#    MAGFAIL  MAGCOL  MAGVIOL  MAGAVE  \
# 0        2       1        4     2.5
# 1        2       1        4     2.5
# 2        4       1        4     3.0
# ...

# %% [markdown]
# # Minor data cleaning
# - Dropping irrelevant columns(redundant month and year information, country code, description variables, PTYPE which holds one value ((going to add back in the value_counts() eventually)) )
# - Dropping remaining null values
# - Converting appropriate columns to datetime for further analysis

# %%
df = df.drop(['MOBEGIN','YRBEGIN','MOEND','YREND','DESC', 'DESC2',"PTYPE"],axis=1)

df.head()
# Out:
#        COUNTRY SCODE  CCODE  YEAR  MAGFAIL  MAGCOL  MAGVIOL  MAGAVE POLITYX  \
# 0  Afghanistan   AFG    700  1978        2       1        4     2.5     REV
# 1  Afghanistan   AFG    700  1979        2       1        4     2.5     NaN
# 2  Afghanistan   AFG    700  1992        4       1        4     3.0     REV
# 3  Afghanistan   AFG    700  1993        4       1        4     3.0     NaN
# 4  Afghanistan   AFG    700  1994        4       1        4     3.0     NaN
#
#   time_begin   time_end
# 0 1978-04-01 1979-12-01
# 1 1978-04-01 1979-12-01
# 2 1992-04-01 1996-09-01
# 3 1992-04-01 1996-09-01
# 4 1992-04-01 1996-09-01

# %%
df = df[df['time_end'].notna()]
df.isnull().sum()
# Out:
# COUNTRY         0
# SCODE           0
# CCODE           0
# YEAR            0
# MAGFAIL         0
# MAGCOL          0
# MAGVIOL         0
# MAGAVE          0
# POLITYX       201
# time_begin      0
# time_end        0
# dtype: int64

# %%
df['time_end']
# Out:
# 0     1979-12-01
# 1     1979-12-01
# 2     1996-09-01
# 3     1996-09-01
# 4     1996-09-01
#          ...
# 348   1972-12-01
# 349   1972-12-01
# 350   1972-12-01
# 351   1996-11-01
# 352   1987-12-01
# Name: time_end, Length: 334, dtype: datetime64[ns]

# %% [markdown]
# # Geographical plotting test - just the most turbulent year
# - Code adapted from https://medium.com/datadriveninvestor/visualising-geospatial-data-with-python-d3b1c519f31

# %%
import folium
import pandas as pd
#Setting up the country co-ordinates
country_geo = 'world-countries.json'

# %%
#looking for most common year to plot
df.YEAR.value_counts()
# Out:
# 1996    12
# 1963    11
# 1965    11
# 1995    11
# 1969    10
#         ..
# 1990     2
# 2005     2
# 1988     1
# 1956     1
# 1952     1
# Name: YEAR, Length: 67, dtype: int64

# %%
crisis_year = 1996

mask = df['YEAR'].isin([crisis_year])

# apply our mask
stage = df[mask]
stage.head()
# Out:
#         COUNTRY SCODE  CCODE  YEAR  MAGFAIL  MAGCOL  MAGVIOL  MAGAVE POLITYX  \
# 6   Afghanistan   AFG    700  1996        2       1        2     1.5     NaN
# 9       Albania   ALB    339  1996        1       3        1     1.5      -5
# 15       Angola   ANG    540  1996        2       1        1     1.5     NaN
# 20      Armenia   ARM    371  1996        1       3        3     2.5     NaN
# 30      Belarus   BLR    370  1996        1       3        1     1.5     NaN
#
#    time_begin   time_end
# 6  1992-04-01 1996-09-01
# 9  1996-05-01 1996-05-01
# 15 1992-05-01 1997-04-01
# 20 1995-07-01 1996-09-01
# 30 1995-04-01 1996-11-01

# %%
#Creating a data frame with just the country codes and the values we want plotted.
data_to_plot = stage[['SCODE','MAGAVE']]
data_to_plot.head()
# Out:
#    SCODE  MAGAVE
# 6    AFG     1.5
# 9    ALB     1.5
# 15   ANG     1.5
# 20   ARM     2.5
# 30   BLR     1.5

# %%
# Setup a folium map at a high-level zoom 
map = folium.Map(location=[100, 0], zoom_start=1.5)

# choropleth maps bind Pandas Data Frames and json geometries. 
#This allows us to quickly visualize data combinations
map.choropleth(geo_data=country_geo, data=data_to_plot,
             columns=['SCODE', 'MAGAVE'],
             key_on='feature.id',
             fill_color='BuPu', fill_opacity=0.7, line_opacity=0.2,
             legend_name='MAGAVE')

map.save('plot_data.html')
# Import the Folium interactive html file


from IPython.display import HTML
HTML('<iframe src=plot_data.html width=700 height=450></iframe>')
# Out:
# <iframe src=plot_data.html width=700 height=450></iframe>

# %%
df.YEAR = pd.to_datetime(df['YEAR'], format='%Y' , errors='coerce')

df.head()
# Out:
#        COUNTRY SCODE  CCODE       YEAR  MAGFAIL  MAGCOL  MAGVIOL  MAGAVE  \
# 0  Afghanistan   AFG    700 1978-01-01        2       1        4     2.5
# 1  Afghanistan   AFG    700 1979-01-01        2       1        4     2.5
# 2  Afghanistan   AFG    700 1992-01-01        4       1        4     3.0
# 3  Afghanistan   AFG    700 1993-01-01        4       1        4     3.0
# 4  Afghanistan   AFG    700 1994-01-01        4       1        4     3.0
#
#   POLITYX time_begin   time_end
# 0     REV 1978-04-01 1979-12-01
# 1     NaN 1978-04-01 1979-12-01
# 2     REV 1992-04-01 1996-09-01
# 3     NaN 1992-04-01 1996-09-01
# 4     NaN 1992-04-01 1996-09-01

# %%
df = df.set_index(pd.DatetimeIndex(df['YEAR']))

df.head()
# Out:
#                 COUNTRY SCODE  CCODE       YEAR  MAGFAIL  MAGCOL  MAGVIOL  \
# YEAR
# 1978-01-01  Afghanistan   AFG    700 1978-01-01        2       1        4
# 1979-01-01  Afghanistan   AFG    700 1979-01-01        2       1        4
# 1992-01-01  Afghanistan   AFG    700 1992-01-01        4       1        4
# 1993-01-01  Afghanistan   AFG    700 1993-01-01        4       1        4
# 1994-01-01  Afghanistan   AFG    700 1994-01-01        4       1        4
#
#             MAGAVE POLITYX time_begin   time_end
# YEAR
# 1978-01-01     2.5     REV 1978-04-01 1979-12-01
# 1979-01-01     2.5     NaN 1978-04-01 1979-12-01
# 1992-01-01     3.0     REV 1992-04-01 1996-09-01
# 1993-01-01     3.0     NaN 1992-04-01 1996-09-01
# 1994-01-01     3.0     NaN 1992-04-01 1996-09-01

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 334 entries, 1978-01-01 to 1987-01-01
# Data columns (total 11 columns):
# COUNTRY       334 non-null object
# SCODE         334 non-null object
# CCODE         334 non-null int64
# YEAR          334 non-null datetime64[ns]
# MAGFAIL       334 non-null int64
# MAGCOL        334 non-null int64
# MAGVIOL       334 non-null int64
# MAGAVE        334 non-null float64
# POLITYX       133 non-null object
# time_begin    334 non-null datetime64[ns]
# time_end      334 non-null datetime64[ns]
# dtypes: datetime64[ns](3), float64(1), int64(4), object(3)
# memory usage: 31.3+ KB

# %% [markdown]
# ## Creation of one hot encoded variables of POLITYX and COUNTRY

# %%
dum_df = pd.get_dummies(df, columns=['POLITYX', "COUNTRY"], prefix='', prefix_sep='')

dum_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 334 entries, 1978-01-01 to 1987-01-01
# Columns: 108 entries, SCODE to Zimbabwe
# dtypes: datetime64[ns](3), float64(1), int64(4), object(1), uint8(99)
# memory usage: 58.4+ KB

# %%
dum_df.head()
# Out:
#            SCODE  CCODE       YEAR  MAGFAIL  MAGCOL  MAGVIOL  MAGAVE  \
# YEAR
# 1978-01-01   AFG    700 1978-01-01        2       1        4     2.5
# 1979-01-01   AFG    700 1979-01-01        2       1        4     2.5
# 1992-01-01   AFG    700 1992-01-01        4       1        4     3.0
# 1993-01-01   AFG    700 1993-01-01        4       1        4     3.0
# 1994-01-01   AFG    700 1994-01-01        4       1        4     3.0
#
#            time_begin   time_end  -18  ...  Thailand  Turkey  USSR  Uganda  \
# YEAR                                   ...
# 1978-01-01 1978-04-01 1979-12-01    0  ...         0       0     0       0
# 1979-01-01 1978-04-01 1979-12-01    0  ...         0       0     0       0
# 1992-01-01 1992-04-01 1996-09-01    0  ...         0       0     0       0
# 1993-01-01 1992-04-01 1996-09-01    0  ...         0       0     0       0
# 1994-01-01 1992-04-01 1996-09-01    0  ...         0       0     0       0
#
# ...

# %% [markdown]
# # Survival analysis - TO DO: By country/region
# ## First converting time_begin and time_end to accepted Lifelines format

# %%
from lifelines.utils import datetimes_to_durations

start_dates = dum_df['time_begin'].to_list()
end_dates = dum_df['time_end'].to_list()

T, E = datetimes_to_durations(start_dates, end_dates, freq="M")

# %%
start_dates
# Out:
# [Timestamp('1978-04-01 00:00:00'),
#  Timestamp('1978-04-01 00:00:00'),
#  Timestamp('1992-04-01 00:00:00'),
#  Timestamp('1992-04-01 00:00:00'),
#  Timestamp('1992-04-01 00:00:00'),
#  Timestamp('1992-04-01 00:00:00'),
#  Timestamp('1992-04-01 00:00:00'),
#  Timestamp('2001-11-01 00:00:00'),
#  Timestamp('2001-11-01 00:00:00'),
#  Timestamp('1996-05-01 00:00:00'),
#  Timestamp('1992-01-01 00:00:00'),
#  Timestamp('1992-05-01 00:00:00'),
#  Timestamp('1992-05-01 00:00:00'),
#  Timestamp('1992-05-01 00:00:00'),
#  Timestamp('1992-05-01 00:00:00'),
#  Timestamp('1992-05-01 00:00:00'),
#  Timestamp('1992-05-01 00:00:00'),
#  Timestamp('1966-06-01 00:00:00'),
#  Timestamp('1976-03-01 00:00:00'),
#  Timestamp('1995-07-01 00:00:00'),
#  Timestamp('1995-07-01 00:00:00'),
#  Timestamp('1993-06-01 00:00:00'),
#  Timestamp('1993-06-01 00:00:00'),
#  Timestamp('1993-06-01 00:00:00'),
#  Timestamp('1963-10-01 00:00:00'),
#  Timestamp('1963-10-01 00:00:00'),
#  Timestamp('1963-10-01 00:00:00'),
# ...

# %%
end_dates
# Out:
# [Timestamp('1979-12-01 00:00:00'),
#  Timestamp('1979-12-01 00:00:00'),
#  Timestamp('1996-09-01 00:00:00'),
#  Timestamp('1996-09-01 00:00:00'),
#  Timestamp('1996-09-01 00:00:00'),
#  Timestamp('1996-09-01 00:00:00'),
#  Timestamp('1996-09-01 00:00:00'),
#  Timestamp('2002-06-01 00:00:00'),
#  Timestamp('2002-06-01 00:00:00'),
#  Timestamp('1996-05-01 00:00:00'),
#  Timestamp('1992-01-01 00:00:00'),
#  Timestamp('1997-04-01 00:00:00'),
#  Timestamp('1997-04-01 00:00:00'),
#  Timestamp('1997-04-01 00:00:00'),
#  Timestamp('1997-04-01 00:00:00'),
#  Timestamp('1997-04-01 00:00:00'),
#  Timestamp('1997-04-01 00:00:00'),
#  Timestamp('1966-06-01 00:00:00'),
#  Timestamp('1976-03-01 00:00:00'),
#  Timestamp('1996-09-01 00:00:00'),
#  Timestamp('1996-09-01 00:00:00'),
#  Timestamp('1995-11-01 00:00:00'),
#  Timestamp('1995-11-01 00:00:00'),
#  Timestamp('1995-11-01 00:00:00'),
#  Timestamp('1965-12-01 00:00:00'),
#  Timestamp('1965-12-01 00:00:00'),
#  Timestamp('1965-12-01 00:00:00'),
# ...

# %% [markdown]
# ## Kaplan Meier Fitter
# - Estimate of the survival function, taking T as a random lifetime taken from population under study (time a couple is married, user time to enter a webpage - an infinite time if a user never does, etc.) that defines the probability of surviving past T
#     - http://en.wikipedia.org/wiki/Kaplan%E2%80%93Meier_estimator

# %%
from lifelines import KaplanMeierFitter
kmf = KaplanMeierFitter()
kmf.fit(T, event_observed=E)
# Out:
# <lifelines.KaplanMeierFitter:"KM_estimate", fitted with 334 total observations, 0 right-censored observations>

# %% [markdown]
# ### Plotting results in months

# %%
kmf.survival_function_.plot()

# %% [markdown]
# - With confidence intervals

# %%
kmf.plot()
plt.savefig("kmf_conf_plot.png")
plt.show()

# %% [markdown]
# - Time at which 50% of regime changes will have ended

# %%
kmf.median_survival_time_
# Out:
# 36.0

# %% [markdown]
# ## NelsonAalenFitter for cumulative hazard function

# %%
from lifelines import NelsonAalenFitter
naf = NelsonAalenFitter()

naf.fit(T,event_observed=E)
# Out:
# <lifelines.NelsonAalenFitter:"NA_estimate", fitted with 334 total observations, 0 right-censored observations>

# %%
print(naf.cumulative_hazard_.head())
naf.plot()
# Out:
#           NA_estimate
# timeline
# 0.0          0.219786
# 1.0          0.227262
# 2.0          0.242386
# 3.0          0.250034
# 4.0          0.257741

# %% [markdown]
# # TO DO: implementing right/left censorship of birth/death events via. groupby country and time resampling

# %% [markdown]
# # Geographic plotting

# %%
# it is a surprise tool that will be useful later meme goes here
# from folium.plugins import TimeSliderChoropleth
